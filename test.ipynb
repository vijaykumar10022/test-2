# %% [markdown]
# 1.)

# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
data=pd.read_csv('Iris.csv')

# %%
data.describe(head(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-f3b022a3d30c> in <module>
# ----> 1 data.describe(head(2))
#
# NameError: name 'head' is not defined

# %%
print("No of  species in Iris is:",len(set(data['Species'])))
# Out:
# No of  species in Iris is: 3

# %% [markdown]
# 2).

# %%
s_ma=max(data['SepalLengthCm'])
s_me=sum(data['SepalLengthCm'])/len(data['SepalLengthCm'])
print("Maximum value in Sepallength is ",max(data['SepalLengthCm']))
print("Mean Value in Sepallength is ",sum(data['SepalLengthCm'])/len(data['SepalLengthCm']))
# Out:
# Maximum value in Sepallength is  7.9
# Mean Value in Sepallength is  5.843333333333335

# %%
p_ma=max(data['PetalLengthCm'])
p_me=sum(data['PetalLengthCm'])/len(data['PetalLengthCm'])
print("Maximum value in Sepallength is ",p_ma)
print("Mean Value in Sepallength is ",p_me)
# Out:
# Maximum value in Sepallength is  6.9
# Mean Value in Sepallength is  3.7586666666666693

# %%
sw_max=max(data['SepalWidthCm'])
sw_me=sum(data['SepalWidthCm'])/len(data['SepalWidthCm'])
print("Maximum value in Sepallength is ",sw_max)
print("Mean Value in Sepallength is ",sw_me)
# Out:
# Maximum value in Sepallength is  4.4
# Mean Value in Sepallength is  3.0540000000000007

# %%
pe_ma=max(data['PetalWidthCm'])
pe_me=sum(data['PetalWidthCm'])/len(data['PetalWidthCm'])
print("Maximum value in Sepallength is ",pe_ma)
print("Mean Value in Sepallength is ",pe_me)
# Out:
# Maximum value in Sepallength is  2.5
# Mean Value in Sepallength is  1.1986666666666672

# %% [markdown]
# 3.scatterplot(for sepallength and petallength)

# %%
plt.scatter(data['SepalLengthCm'],data['PetalLengthCm'])

# %% [markdown]
# 5.jointplot(for sepallength and sepalwidth)

# %%
import seaborn as sns

# %%
sns.jointplot(data['SepalLengthCm'],data['SepalWidthCm'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# 6.facetgrid(for sepallength and sepalwidth for all species)

# %%
df=pd.read_csv('Iris.csv')
sns.factorplot('SepalLengthCm','SepalWidthCm','Species',data=df,kind="bar",palette="muted",legend=True)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Admin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# 7.boxplot(for species and sepalwidth)

# %%
sns.boxplot(data['Species'],data['SepalWidthCm'])

# %% [markdown]
# 8.boxplot & stripplot(for sepallength and all species)

# %%
sns.stripplot("Species","SepalLengthCm",data=data)
sns.boxplot("Species","SepalLengthCm",data=data)

# %% [markdown]
# 9.violinplot(for petallength and all species)

# %%
sns.violinplot("PetalLengthCm","Species",data=data,inner="points")

# %% [markdown]
# 10.pairplot(for all 4 columns with species)

# %%
sns.set_style("ticks")
sns.pairplot(data,hue="Species",diag_kind="kde",kind="scatter",palette="husl")
plt.show()
